# %% [markdown]
# ### Title: Exercice 7.2
# ### Author: Jerock Kalala
# ### Date: October 14th 2022
# ### Professor: Dr. Brett Werner
# ### Working with Matrices

# %% [markdown]
# ##### 1. Enter each of the matrices A, B, and C as Numpy matrix.

# %%
import numpy as np

A = np.array([[1,-2,3,7], [2,1,1,4], [-3,2,-2,10]])
B = np.array([[0,1,-3,-2], [10,-1,2,-3], [5,1,-1,4]])
C = np.array([[4,0,-2,3], [3,6,9,7], [2,2,5,1], [9,4,6,-2]])
print("Matrix A=","\n", A), print()
print("Matrix B=", "\n", B, "\n")
print("Matrix C=", "\n", C)
# Out:
# Matrix A=
#  [[ 1 -2  3  7]
#  [ 2  1  1  4]
#  [-3  2 -2 10]]
#
# Matrix B=
#  [[ 0  1 -3 -2]
#  [10 -1  2 -3]
#  [ 5  1 -1  4]]
#
# Matrix C=
#  [[ 4  0 -2  3]
#  [ 3  6  9  7]
#  [ 2  2  5  1]
#  [ 9  4  6 -2]]

# %% [markdown]
# ##### 2. What are the dimensions of each of the matrices A, B, and C? Display these using Python code.

# %%
print("The dimension of the Matrix A is : ", A.shape)
print("The dimension of the Matrix B is : ", B.shape)
print("The dimension of the Matrix c is : ", C.shape)
# Out:
# The dimension of the Matrix A is :  (3, 4)
# The dimension of the Matrix B is :  (3, 4)
# The dimension of the Matrix c is :  (4, 4)

# %% [markdown]
# ##### 3. Determine if each of the following matrix operations is defined. If it is defined, calculate the result using Python. If it is not defined, explain why it is not defined.

# %%
print(" ----a) A + B\n")
print("The some of matrix A and B is: \n", A + B)
print("\nA+B is define")
print('\n-----b) AB: \n\nIn order for matrix multiplication to be defined, the number of columns in the first matrix must be equal to the number of rows in the second matrix. This being said, AB in not defined')
print("\n-----c) AC: \nThe multiplication of matrix A and C is: ")
print(A.dot(C))
print("\nAC is define")
print("\n-----d) C: \nThe transposition of matrix C is:")
print(A.T)
# Out:
#  ----a) A + B
#
# The some of matrix A and B is:
#  [[ 1 -1  0  5]
#  [12  0  3  1]
#  [ 2  3 -3 14]]
#
# A+B is define
#
# -----b) AB:
#
# In order for matrix multiplication to be defined, the number of columns in the first matrix must be equal to the number of rows in the second matrix. This being said, AB in not defined
#
# -----c) AC:
# The multiplication of matrix A and C is:
# [[ 67  22  37 -22]
#  [ 49  24  34   6]
#  [ 80  48  74 -17]]
#
# AC is define
#
# -----d) C:
# The transposition of matrix C is:
# [[ 1  2 -3]
#  [-2  1  2]
#  [ 3  1 -2]
#  [ 7  4 10]]

# %% [markdown]
# ##### 4. Illustrate the following property of matrix transpositions using these matrices: (A + B)^T  =  (A^T) + (B^T) .

# %%
print((A+B).T, "\n\n=\n\n", (A.T)+(B.T))
# Out:
# [[ 1 12  2]
#  [-1  0  3]
#  [ 0  3 -3]
#  [ 5  1 14]]
#
# =
#
#  [[ 1 12  2]
#  [-1  0  3]
#  [ 0  3 -3]
#  [ 5  1 14]]

# %% [markdown]
# ##### 5. Illustrate the following property of matrix transposition using these matrices (AC)^T = (C^T)(A^T).

# %%
print((A.dot(C)).T, "\n\n=\n\n", (C.T).dot(A.T))
# Out:
# [[ 67  49  80]
#  [ 22  24  48]
#  [ 37  34  74]
#  [-22   6 -17]]
#
# =
#
#  [[ 67  49  80]
#  [ 22  24  48]
#  [ 37  34  74]
#  [-22   6 -17]]

# %% [markdown]
# ##### 6. Fine C^-1 using Python code.

# %%
C_inv = np.linalg.inv(C)
C_inv
# Out:
# array([[ 0.14814815, -0.07407407,  0.14814815,  0.03703704],
#        [-0.3       ,  0.35      , -1.05      ,  0.25      ],
#        [ 0.02962963, -0.11481481,  0.52962963, -0.09259259],
#        [ 0.15555556,  0.02222222,  0.15555556, -0.11111111]])

# %% [markdown]
# #### Working with Images

# %% [markdown]
# ##### 1. Use the following code to display the image.

# %%
import cv2 #import the OpenCV library to read images # I have tried to install the cv2 library, but it didn't work.
import matplotlib.pyplot as plt #import matplotlib to display the image

# import the image; by default, OpenCV imports images in the BGR format
image_bgr = cv2.imread('E:\\Bellevue\\Fall_2022\\DSC_320_Math for Data Science\\Week_7\\week7data\\week7_image.jpg',cv2.IMREAD_COLOR)

# convert the image to the RGB format
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Display the image
print("1. Display the image")
plt.imshow(image_rgb)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 import cv2 #import the OpenCV libarry to read impages
#       2 import matplotlib.pyplot as plt #import matplotlib to display the image
#       4 # import the image; by default, OpenCV imports images in the BGR format
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# image using matplotlib As cv2 didn't work on my PC after failed attempt to import and install the cv2 package
# importing matplotlib modules
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Read Images
image_bgr = mpimg.imread("E:\\Bellevue\\Fall_2022\\DSC_320_Math for Data Science\\Week_7\\week7data\\week7_image.jpg")
# Output Images
plt.imshow(image_bgr)

# %% [markdown]
# ##### 2. Find the resolution of this image. Hint: OpenCV imports the image as a Numpy array, where each pixel corresponds to an entry in the array.

# %%
print(image_bgr.shape)
print("The resolution og the above image is: 453 x 600" )
# Out:
# (453, 600, 3)
# The resolution og the above image is: 453 x 600

# %% [markdown]
# ##### 3. In checking the array dimensions, you should see that three numbers are displayed. What is this third number, and why is it there?

# %%
print("Image have the following dimensions:height, width and color. This means the third number '3' is there to represent the colors of the Bruins image. '453' and '600' represent respectively the height and the width." )
# Out:
# Image have the following dimensions:height, width and color. This means the third number '3' is there to represent the colors of the Bruins image. '453' and '600' represent respectively the height and the width.
